# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with your API key
with open("API_Key.txt") as file:
    API_key = file.read()
API_key = API_key.strip()

# %% [markdown]
# ### How to pull stock data with the alpha_vantage Python package 1

# %%
#install Alpha Vantage Python package
# %pip install alpha_vantage
# Out:
# Collecting alpha_vantage
#   Downloading alpha_vantage-2.3.1-py3-none-any.whl (31 kB)
# Collecting aiohttp (from alpha_vantage)
#   Obtaining dependency information for aiohttp from https://files.pythonhosted.org/packages/41/8e/4c48881316bbced3d13089c4d0df4be321ce79a0c695d82dee9996aaf56b/aiohttp-3.8.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading aiohttp-3.8.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from alpha_vantage) (2.31.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp->alpha_vantage) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp->alpha_vantage) (3.2.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->alpha_vantage)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 5.0 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->alpha_vantage)
#   Obtaining dependency information for async-timeout<5.0,>=4.0.0a3 from https://files.pythonhosted.org/packages/a7/fa/e01228c2938de91d47b307831c62ab9e4001e747789d0b05baf779a6488c/async_timeout-4.0.3-py3-none-any.whl.metadata
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->alpha_vantage)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 13.5 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->alpha_vantage)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/1e/28/74b8b6451c89c070d34e753d8b65a1e4ce508a6808b18529f36e8c0e2184/frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->alpha_vantage)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->alpha_vantage) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->alpha_vantage) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->alpha_vantage) (2023.7.22)
# Downloading aiohttp-3.8.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.2 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 12.3 MB/s eta 0:00:00
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, alpha_vantage
# Successfully installed aiohttp-3.8.6 aiosignal-1.3.1 alpha_vantage-2.3.1 async-timeout-4.0.3 frozenlist-1.4.0 multidict-6.0.4 yarl-1.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
ts1 = TimeSeries(key=API_key)

# %%
#get monthly stock data of Apple
ts1.get_monthly(symbol='APC')
# Out:
# ({'2019-08-08': {'1. open': '73.6100',
#    '2. high': '74.6000',
#    '3. low': '71.9700',
#    '4. close': '72.7700',
#    '5. volume': '95641549'},
#   '2019-07-31': {'1. open': '70.9400',
#    '2. high': '74.0700',
#    '3. low': '70.4700',
#    '4. close': '73.6600',
#    '5. volume': '157870565'},
#   '2019-06-28': {'1. open': '70.4400',
#    '2. high': '71.2400',
#    '3. low': '69.6100',
#    '4. close': '70.5600',
#    '5. volume': '175472403'},
#   '2019-05-31': {'1. open': '72.6600',
#    '2. high': '76.2300',
#    '3. low': '69.5300',
#    '4. close': '70.3700',
#    '5. volume': '305530634'},
#   '2019-04-30': {'1. open': '46.1200',
#    '2. high': '73.6200',
#    '3. low': '44.0300',
#    '4. close': '72.8500',
#    '5. volume': '363145833'},
#   '2019-03-29': {'1. open': '43.7700',
#    '2. high': '46.2700',
#    '3. low': '41.5100',
#    '4. close': '45.4800',
#    '5. volume': '100140742'},
#   '2019-02-28': {'1. open': '47.6700',
#    '2. high': '49.6400',
#    '3. low': '40.9100',
#    '4. close': '43.5000',
#    '5. volume': '131421101'},
#   '2019-01-31': {'1. open': '42.9000',
#    '2. high': '49.2400',
#    '3. low': '42.2500',
#    '4. close': '47.3300',
#    '5. volume': '96179984'},
#   '2018-12-31': {'1. open': '54.8900',
#    '2. high': '55.8200',
#    '3. low': '40.4000',
#    '4. close': '43.8400',
#    '5. volume': '106318047'},
#   '2018-11-30': {'1. open': '53.5700',
#    '2. high': '60.1400',
#    '3. low': '51.2800',
#    '4. close': '52.9000',
#    '5. volume': '126478520'},
#   '2018-10-31': {'1. open': '67.7700',
#    '2. high': '71.1100',
#    '3. low': '52.9900',
#    '4. close': '53.2000',
#    '5. volume': '100380298'},
#   '2018-09-28': {'1. open': '64.4100',
#    '2. high': '67.8000',
#    '3. low': '60.5500',
#    '4. close': '67.4100',
#    '5. volume': '75420800'},
#   '2018-08-31': {'1. open': '71.9500',
#    '2. high': '72.0500',
#    '3. low': '61.7500',
#    '4. close': '64.4000',
#    '5. volume': '127456317'},
#   '2018-07-31': {'1. open': '72.7000',
#    '2. high': '76.7000',
#    '3. low': '70.1200',
#    '4. close': '73.1500',
#    '5. volume': '69201224'},
#   '2018-06-29': {'1. open': '69.9600',
#    '2. high': '75.5000',
#    '3. low': '67.5400',
#    '4. close': '73.2500',
#    '5. volume': '103856192'},
#   '2018-05-31': {'1. open': '67.1700',
#    '2. high': '72.7000',
#    '3. low': '64.7900',
#    '4. close': '69.8000',
#    '5. volume': '106190920'},
#   '2018-04-30': {'1. open': '60.0900',
#    '2. high': '68.1800',
#    '3. low': '56.7900',
#    '4. close': '67.3200',
#    '5. volume': '107317348'},
#   '2018-03-29': {'1. open': '57.1900',
#    '2. high': '63.0500',
#    '3. low': '56.0400',
#    '4. close': '60.4100',
#    '5. volume': '108523187'},
#   '2018-02-28': {'1. open': '60.5800',
#    '2. high': '61.5000',
#    '3. low': '53.8500',
#    '4. close': '57.0400',
#    '5. volume': '121755865'},
#   '2018-01-31': {'1. open': '54.1300',
#    '2. high': '62.5100',
#    '3. low': '54.0000',
#    '4. close': '60.0500',
#    '5. volume': '110857964'},
#   '2017-12-29': {'1. open': '48.6000',
#    '2. high': '54.4500',
#    '3. low': '46.8000',
#    '4. close': '53.6400',
#    '5. volume': '104794940'},
#   '2017-11-30': {'1. open': '49.6400',
#    '2. high': '52.1700',
#    '3. low': '47.0100',
#    '4. close': '48.0900',
#    '5. volume': '124985458'},
#   '2017-10-31': {'1. open': '47.8800',
#    '2. high': '50.1047',
#    '3. low': '46.7450',
#    '4. close': '49.3700',
#    '5. volume': '120452180'},
#   '2017-09-29': {'1. open': '40.9900',
#    '2. high': '50.1600',
#    '3. low': '40.4100',
#    '4. close': '48.8500',
#    '5. volume': '98627386'},
#   '2017-08-31': {'1. open': '45.6000',
#    '2. high': '45.7300',
#    '3. low': '39.9600',
#    '4. close': '40.9300',
#    '5. volume': '101884673'},
#   '2017-07-31': {'1. open': '45.5000',
#    '2. high': '47.9500',
#    '3. low': '42.5800',
#    '4. close': '45.6700',
#    '5. volume': '104449908'},
#   '2017-06-30': {'1. open': '50.7300',
#    '2. high': '51.5000',
#    '3. low': '43.4510',
#    '4. close': '45.3400',
#    '5. volume': '121232478'},
#   '2017-05-31': {'1. open': '56.9300',
#    '2. high': '57.4400',
#    '3. low': '50.0000',
#    '4. close': '50.5300',
#    '5. volume': '141987073'},
#   '2017-04-28': {'1. open': '61.9000',
#    '2. high': '64.1500',
#    '3. low': '55.5700',
#    '4. close': '57.0200',
#    '5. volume': '75698366'},
#   '2017-03-31': {'1. open': '65.4900',
#    '2. high': '66.6600',
#    '3. low': '59.3400',
#    '4. close': '62.0000',
#    '5. volume': '102419964'},
#   '2017-02-28': {'1. open': '70.2700',
#    '2. high': '71.2500',
#    '3. low': '64.0000',
#    '4. close': '64.6500',
#    '5. volume': '83664780'},
#   '2017-01-31': {'1. open': '70.5600',
#    '2. high': '72.3190',
#    '3. low': '67.3700',
#    '4. close': '69.5300',
#    '5. volume': '73225172'},
#   '2016-12-30': {'1. open': '70.7700',
#    '2. high': '73.3300',
#    '3. low': '66.5100',
#    '4. close': '69.7300',
#    '5. volume': '86800666'},
#   '2016-11-30': {'1. open': '60.1500',
#    '2. high': '69.4800',
#    '3. low': '58.5900',
#    '4. close': '69.1500',
#    '5. volume': '112040875'},
#   '2016-10-31': {'1. open': '63.1800',
#    '2. high': '65.0800',
#    '3. low': '59.3500',
#    '4. close': '59.4400',
#    '5. volume': '92442997'},
#   '2016-09-30': {'1. open': '53.1200',
#    '2. high': '63.8400',
#    '3. low': '52.6000',
#    '4. close': '63.3600',
#    '5. volume': '168070674'},
#   '2016-08-31': {'1. open': '53.8800',
#    '2. high': '57.1800',
#    '3. low': '50.2300',
#    '4. close': '53.4700',
#    '5. volume': '92483821'},
#   '2016-07-29': {'1. open': '53.7900',
#    '2. high': '58.0400',
#    '3. low': '52.3200',
#    '4. close': '54.5300',
#    '5. volume': '87002416'},
#   '2016-06-30': {'1. open': '51.0800',
#    '2. high': '57.0000',
#    '3. low': '48.6700',
#    '4. close': '53.2500',
#    '5. volume': '97180121'},
#   '2016-05-31': {'1. open': '52.6200',
#    '2. high': '53.0000',
#    '3. low': '44.8100',
#    '4. close': '51.8600',
#    '5. volume': '113211829'},
#   '2016-04-29': {'1. open': '45.0700',
#    '2. high': '55.4600',
#    '3. low': '43.5200',
#    '4. close': '52.7600',
#    '5. volume': '115614870'},
#   '2016-03-31': {'1. open': '39.1600',
#    '2. high': '50.3900',
#    '3. low': '37.6500',
#    '4. close': '46.5700',
#    '5. volume': '177050233'},
#   '2016-02-29': {'1. open': '38.5400',
#    '2. high': '44.0600',
#    '3. low': '33.8500',
#    '4. close': '37.9500',
#    '5. volume': '204618399'},
#   '2016-01-29': {'1. open': '48.5100',
#    '2. high': '50.0000',
#    '3. low': '28.1600',
#    '4. close': '39.0900',
#    '5. volume': '233485054'},
#   '2015-12-31': {'1. open': '60.0900',
#    '2. high': '61.1900',
#    '3. low': '44.5000',
#    '4. close': '48.5800',
#    '5. volume': '173590495'},
#   '2015-11-30': {'1. open': '65.8400',
#    '2. high': '72.2400',
#    '3. low': '57.8600',
#    '4. close': '59.9000',
#    '5. volume': '126212613'},
#   '2015-10-30': {'1. open': '61.3400',
#    '2. high': '73.8700',
#    '3. low': '59.7500',
#    '4. close': '66.8800',
#    '5. volume': '107902359'},
#   '2015-09-30': {'1. open': '69.4200',
#    '2. high': '71.3200',
#    '3. low': '58.2909',
#    '4. close': '60.3900',
#    '5. volume': '89558526'},
#   '2015-08-31': {'1. open': '73.6100',
#    '2. high': '78.5900',
#    '3. low': '58.1000',
#    '4. close': '71.5800',
#    '5. volume': '114564943'},
#   '2015-07-31': {'1. open': '78.2600',
#    '2. high': '78.7000',
#    '3. low': '69.4003',
#    '4. close': '74.3500',
#    '5. volume': '99946648'},
#   '2015-06-30': {'1. open': '83.9600',
#    '2. high': '85.4300',
#    '3. low': '77.7526',
#    '4. close': '78.0600',
#    '5. volume': '66209809'},
#   '2015-05-29': {'1. open': '93.9300',
#    '2. high': '95.7500',
#    '3. low': '82.8310',
#    '4. close': '83.6100',
#    '5. volume': '84390674'},
#   '2015-04-30': {'1. open': '83.7600',
#    '2. high': '95.9400',
#    '3. low': '82.9200',
#    '4. close': '94.1000',
#    '5. volume': '90761560'},
#   '2015-03-31': {'1. open': '83.3800',
#    '2. high': '84.0800',
#    '3. low': '77.0000',
#    '4. close': '82.8100',
#    '5. volume': '90165630'},
#   '2015-02-27': {'1. open': '83.0050',
#    '2. high': '90.1000',
#    '3. low': '80.7600',
#    '4. close': '84.2300',
#    '5. volume': '100453998'},
#   '2015-01-30': {'1. open': '80.9700',
#    '2. high': '84.1400',
#    '3. low': '73.8200',
#    '4. close': '81.7500',
#    '5. volume': '115446488'},
#   '2014-12-31': {'1. open': '78.0000',
#    '2. high': '85.2100',
#    '3. low': '71.0000',
#    '4. close': '82.5000',
#    '5. volume': '140846514'},
#   '2014-11-28': {'1. open': '92.5300',
#    '2. high': '95.9360',
#    '3. low': '78.6600',
#    '4. close': '79.1500',
#    '5. volume': '104186833'},
#   '2014-10-31': {'1. open': '101.4400',
#    '2. high': '102.6800',
#    '3. low': '80.9800',
#    '4. close': '91.7800',
#    '5. volume': '183722475'},
#   '2014-09-30': {'1. open': '112.0800',
#    '2. high': '112.9900',
#    '3. low': '100.4000',
#    '4. close': '101.4400',
#    '5. volume': '78019696'},
#   '2014-08-29': {'1. open': '105.8700',
#    '2. high': '113.5100',
#    '3. low': '104.5000',
#    '4. close': '112.6900',
#    '5. volume': '74505500'},
#   '2014-07-31': {'1. open': '110.7200',
#    '2. high': '113.0000',
#    '3. low': '104.4500',
#    '4. close': '106.8500',
#    '5. volume': '91255400'},
#   '2014-06-30': {'1. open': '103.2300',
#    '2. high': '112.0600',
#    '3. low': '100.4810',
#    '4. close': '109.4700',
#    '5. volume': '70806100'},
#   '2014-05-30': {'1. open': '99.1500',
#    '2. high': '104.8400',
#    '3. low': '97.6301',
#    '4. close': '102.8600',
#    '5. volume': '74948600'},
#   '2014-04-30': {'1. open': '84.8800',
#    '2. high': '103.5000',
#    '3. low': '84.5400',
#    '4. close': '99.0200',
#    '5. volume': '159096900'},
#   '2014-03-31': {'1. open': '83.9200',
#    '2. high': '86.8600',
#    '3. low': '81.4200',
#    '4. close': '84.7600',
#    '5. volume': '82547500'},
#   '2014-02-28': {'1. open': '80.7300',
#    '2. high': '85.2100',
#    '3. low': '78.1500',
#    '4. close': '84.1600',
#    '5. volume': '80185200'},
#   '2014-01-31': {'1. open': '79.0300',
#    '2. high': '83.9700',
#    '3. low': '77.8000',
#    '4. close': '80.6900',
#    '5. volume': '96863500'},
#   '2013-12-31': {'1. open': '88.9200',
#    '2. high': '89.7000',
#    '3. low': '73.6000',
#    '4. close': '79.3200',
#    '5. volume': '129986800'},
#   '2013-11-29': {'1. open': '95.4400',
#    '2. high': '96.5400',
#    '3. low': '87.6600',
#    '4. close': '88.8200',
#    '5. volume': '61859800'},
#   '2013-10-31': {'1. open': '92.8900',
#    '2. high': '98.4740',
#    '3. low': '91.2700',
#    '4. close': '95.2900',
#    '5. volume': '62767900'},
#   '2013-09-30': {'1. open': '92.4300',
#    '2. high': '96.7500',
#    '3. low': '91.7000',
#    '4. close': '92.9900',
#    '5. volume': '49039400'},
#   '2013-08-30': {'1. open': '89.4700',
#    '2. high': '93.1400',
#    '3. low': '87.5700',
#    '4. close': '91.4200',
#    '5. volume': '59829700'},
#   '2013-07-31': {'1. open': '86.3300',
#    '2. high': '92.9000',
#    '3. low': '86.0800',
#    '4. close': '88.5200',
#    '5. volume': '64725200'},
#   '2013-06-28': {'1. open': '87.8500',
#    '2. high': '89.0850',
#    '3. low': '80.4400',
#    '4. close': '85.9300',
#    '5. volume': '56756600'},
#   '2013-05-31': {'1. open': '84.1700',
#    '2. high': '92.1800',
#    '3. low': '82.5200',
#    '4. close': '87.4700',
#    '5. volume': '72161500'},
#   '2013-04-30': {'1. open': '87.1600',
#    '2. high': '87.9500',
#    '3. low': '78.3000',
#    '4. close': '84.7600',
#    '5. volume': '74960700'},
#   '2013-03-28': {'1. open': '78.8700',
#    '2. high': '89.2000',
#    '3. low': '78.2900',
#    '4. close': '87.4500',
#    '5. volume': '67590700'},
#   '2013-02-28': {'1. open': '80.8000',
#    '2. high': '84.8300',
#    '3. low': '77.0100',
#    '4. close': '79.5800',
#    '5. volume': '63460000'},
#   '2013-01-31': {'1. open': '75.7500',
#    '2. high': '81.8800',
#    '3. low': '74.7300',
#    '4. close': '80.0200',
#    '5. volume': '69018900'},
#   '2012-12-31': {'1. open': '73.9500',
#    '2. high': '76.9500',
#    '3. low': '71.7650',
#    '4. close': '74.3100',
#    '5. volume': '59187500'},
#   '2012-11-30': {'1. open': '68.7200',
#    '2. high': '74.6700',
#    '3. low': '68.5600',
#    '4. close': '73.1900',
#    '5. volume': '73545000'},
#   '2012-10-31': {'1. open': '70.5500',
#    '2. high': '72.5200',
#    '3. low': '65.8200',
#    '4. close': '68.8100',
#    '5. volume': '63446900'},
#   '2012-09-28': {'1. open': '69.3200',
#    '2. high': '76.6300',
#    '3. low': '68.1700',
#    '4. close': '69.9200',
#    '5. volume': '72330300'},
#   '2012-08-31': {'1. open': '69.9100',
#    '2. high': '71.0900',
#    '3. low': '65.3800',
#    '4. close': '69.2700',
#    '5. volume': '81652000'},
#   '2012-07-31': {'1. open': '66.1800',
#    '2. high': '74.1300',
#    '3. low': '64.1900',
#    '4. close': '69.4400',
#    '5. volume': '117278500'},
#   '2012-06-29': {'1. open': '58.9300',
#    '2. high': '66.2200',
#    '3. low': '56.4200',
#    '4. close': '66.2000',
#    '5. volume': '120153200'},
#   '2012-05-31': {'1. open': '74.0500',
#    '2. high': '76.0200',
#    '3. low': '59.5600',
#    '4. close': '61.0000',
#    '5. volume': '105036900'},
#   '2012-04-30': {'1. open': '78.2500',
#    '2. high': '79.8500',
#    '3. low': '69.7800',
#    '4. close': '73.2100',
#    '5. volume': '72516900'},
#   '2012-03-30': {'1. open': '84.7800',
#    '2. high': '87.3700',
#    '3. low': '75.9000',
#    '4. close': '78.3400',
#    '5. volume': '94141500'},
#   '2012-02-29': {'1. open': '81.3700',
#    '2. high': '88.7000',
#    '3. low': '80.4200',
#    '4. close': '84.1200',
#    '5. volume': '80648900'},
#   '2012-01-31': {'1. open': '78.3600',
#    '2. high': '82.4700',
#    '3. low': '77.6000',
#    '4. close': '80.7200',
#    '5. volume': '69672500'},
#   '2011-12-30': {'1. open': '80.7400',
#    '2. high': '82.6300',
#    '3. low': '71.1800',
#    '4. close': '76.3300',
#    '5. volume': '61612700'},
#   '2011-11-30': {'1. open': '74.2700',
#    '2. high': '84.4200',
#    '3. low': '71.2529',
#    '4. close': '81.2700',
#    '5. volume': '90421900'},
#   '2011-10-31': {'1. open': '62.1700',
#    '2. high': '83.9800',
#    '3. low': '57.1100',
#    '4. close': '78.5000',
#    '5. volume': '114628400'},
#   '2011-09-30': {'1. open': '73.6900',
#    '2. high': '77.4500',
#    '3. low': '63.0300',
#    '4. close': '63.0500',
#    '5. volume': '96636200'},
#   '2011-08-31': {'1. open': '83.8000',
#    '2. high': '84.0000',
#    '3. low': '63.2600',
#    '4. close': '73.7500',
#    '5. volume': '122168200'},
#   '2011-07-29': {'1. open': '76.7600',
#    '2. high': '85.2500',
#    '3. low': '75.8001',
#    '4. close': '82.5600',
#    '5. volume': '70527900'},
#   '2011-06-30': {'1. open': '79.0200',
#    '2. high': '79.6000',
#    '3. low': '68.6700',
#    '4. close': '76.7600',
#    '5. volume': '102336100'},
#   '2011-05-31': {'1. open': '79.5400',
#    '2. high': '81.5800',
#    '3. low': '71.1000',
#    '4. close': '79.5200',
#    '5. volume': '100522300'},
#   '2011-04-29': {'1. open': '83.3900',
#    '2. high': '85.5000',
#    '3. low': '76.8600',
#    '4. close': '78.9400',
#    '5. volume': '64470400'},
#   '2011-03-31': {'1. open': '81.9800',
#    '2. high': '84.0000',
#    '3. low': '73.3500',
#    '4. close': '81.9200',
#    '5. volume': '74581100'},
#   '2011-02-28': {'1. open': '77.1500',
#    '2. high': '82.9200',
#    '3. low': '75.5400',
#    '4. close': '81.8300',
#    '5. volume': '77314000'},
#   '2011-01-31': {'1. open': '77.3300',
#    '2. high': '79.8500',
#    '3. low': '73.0200',
#    '4. close': '77.0800',
#    '5. volume': '89824800'},
#   '2010-12-31': {'1. open': '65.3800',
#    '2. high': '78.9800',
#    '3. low': '65.1500',
#    '4. close': '76.1600',
#    '5. volume': '92521400'},
#   '2010-11-30': {'1. open': '62.3100',
#    '2. high': '67.6800',
#    '3. low': '61.3400',
#    '4. close': '64.1600',
#    '5. volume': '97277600'},
#   '2010-10-29': {'1. open': '57.9600',
#    '2. high': '63.9300',
#    '3. low': '55.6500',
#    '4. close': '61.5700',
#    '5. volume': '90136200'},
#   '2010-09-30': {'1. open': '47.3400',
#    '2. high': '58.4200',
#    '3. low': '47.1800',
#    '4. close': '57.0500',
#    '5. volume': '110854300'},
#   '2010-08-31': {'1. open': '50.7100',
#    '2. high': '56.9700',
#    '3. low': '45.0700',
#    '4. close': '45.9900',
#    '5. volume': '127371900'},
#   '2010-07-30': {'1. open': '36.9300',
#    '2. high': '51.0200',
#    '3. low': '36.0600',
#    '4. close': '49.1600',
#    '5. volume': '185245900'},
#   '2010-06-30': {'1. open': '46.4200',
#    '2. high': '48.2300',
#    '3. low': '34.5400',
#    '4. close': '36.0900',
#    '5. volume': '444524900'},
#   '2010-05-28': {'1. open': '61.1000',
#    '2. high': '66.1700',
#    '3. low': '50.6240',
#    '4. close': '52.3300',
#    '5. volume': '216845700'},
#   '2010-04-30': {'1. open': '73.7200',
#    '2. high': '75.0700',
#    '3. low': '61.7100',
#    '4. close': '62.1600',
#    '5. volume': '107909300'},
#   '2010-03-31': {'1. open': '70.5000',
#    '2. high': '73.8900',
#    '3. low': '68.0500',
#    '4. close': '72.8300',
#    '5. volume': '91032900'},
#   '2010-02-26': {'1. open': '64.4200',
#    '2. high': '70.5900',
#    '3. low': '60.7500',
#    '4. close': '70.1300',
#    '5. volume': '81306100'},
#   '2010-01-29': {'1. open': '63.6000',
#    '2. high': '68.2000',
#    '3. low': '62.9800',
#    '4. close': '63.7800',
#    '5. volume': '76984400'},
#   '2009-12-31': {'1. open': '60.6500',
#    '2. high': '64.9700',
#    '3. low': '55.8700',
#    '4. close': '62.4200',
#    '5. volume': '97325300'},
#   '2009-11-30': {'1. open': '61.2800',
#    '2. high': '66.6500',
#    '3. low': '58.7000',
#    '4. close': '59.5300',
#    '5. volume': '89117700'},
#   '2009-10-30': {'1. open': '62.4400',
#    '2. high': '69.3700',
#    '3. low': '58.1700',
#    '4. close': '60.9300',
#    '5. volume': '127221300'},
#   '2009-09-30': {'1. open': '52.6700',
#    '2. high': '66.2100',
#    '3. low': '52.4400',
#    '4. close': '62.7300',
#    '5. volume': '143827700'},
#   '2009-08-31': {'1. open': '49.5000',
#    '2. high': '55.5000',
#    '3. low': '48.8500',
#    '4. close': '52.8700',
#    '5. volume': '98562900'},
#   '2009-07-31': {'1. open': '45.8700',
#    '2. high': '49.3700',
#    '3. low': '40.2800',
#    '4. close': '48.2000',
#    '5. volume': '127468800'},
#   '2009-06-30': {'1. open': '48.6700',
#    '2. high': '51.5900',
#    '3. low': '42.5000',
#    '4. close': '45.3900',
#    '5. volume': '147684800'},
#   '2009-05-29': {'1. open': '43.0400',
#    '2. high': '52.3800',
#    '3. low': '41.6500',
#    '4. close': '47.7800',
#    '5. volume': '193195900'},
#   '2009-04-30': {'1. open': '38.0500',
#    '2. high': '45.2800',
#    '3. low': '37.8000',
#    '4. close': '43.0600',
#    '5. volume': '117170100'},
#   '2009-03-31': {'1. open': '33.7500',
#    '2. high': '44.0000',
#    '3. low': '30.8800',
#    '4. close': '38.8900',
#    '5. volume': '175997700'},
#   '2009-02-27': {'1. open': '35.9900',
#    '2. high': '43.0000',
#    '3. low': '33.2200',
#    '4. close': '34.9500',
#    '5. volume': '154733200'},
#   '2009-01-30': {'1. open': '38.7500',
#    '2. high': '43.9800',
#    '3. low': '34.8500',
#    '4. close': '36.7400',
#    '5. volume': '149803400'},
#   '2008-12-31': {'1. open': '38.5400',
#    '2. high': '41.9400',
#    '3. low': '31.0200',
#    '4. close': '38.5500',
#    '5. volume': '148285700'},
#   '2008-11-28': {'1. open': '35.4900',
#    '2. high': '41.3500',
#    '3. low': '29.0000',
#    '4. close': '41.0500',
#    '5. volume': '186276000'},
#   '2008-10-31': {'1. open': '48.9000',
#    '2. high': '49.7000',
#    '3. low': '24.5700',
#    '4. close': '35.3000',
#    '5. volume': '272029600'},
#   '2008-09-30': {'1. open': '59.5400',
#    '2. high': '61.3100',
#    '3. low': '43.2700',
#    '4. close': '48.5100',
#    '5. volume': '199367200'},
#   '2008-08-29': {'1. open': '57.2500',
#    '2. high': '63.6100',
#    '3. low': '52.3000',
#    '4. close': '61.7300',
#    '5. volume': '158837900'},
#   '2008-07-31': {'1. open': '75.2000',
#    '2. high': '75.9000',
#    '3. low': '56.0200',
#    '4. close': '57.9100',
#    '5. volume': '167446300'},
#   '2008-06-30': {'1. open': '74.6200',
#    '2. high': '81.1400',
#    '3. low': '71.6800',
#    '4. close': '74.8400',
#    '5. volume': '121027500'},
#   '2008-05-30': {'1. open': '65.7700',
#    '2. high': '81.3600',
#    '3. low': '62.7000',
#    '4. close': '74.9700',
#    '5. volume': '136492200'},
#   '2008-04-30': {'1. open': '62.6100',
#    '2. high': '71.1200',
#    '3. low': '61.3400',
#    '4. close': '66.5600',
#    '5. volume': '102409600'},
#   '2008-03-31': {'1. open': '63.8600',
#    '2. high': '67.2500',
#    '3. low': '57.8900',
#    '4. close': '63.0300',
#    '5. volume': '108425300'},
#   '2008-02-29': {'1. open': '59.3000',
#    '2. high': '66.2400',
#    '3. low': '52.4200',
#    '4. close': '63.7400',
#    '5. volume': '105652700'},
#   '2008-01-31': {'1. open': '66.4200',
#    '2. high': '67.6300',
#    '3. low': '50.9100',
#    '4. close': '58.4800',
#    '5. volume': '121492700'},
#   '2007-12-31': {'1. open': '56.4500',
#    '2. high': '68.0000',
#    '3. low': '56.3600',
#    '4. close': '65.6900',
#    '5. volume': '73015400'},
#   '2007-11-30': {'1. open': '59.0200',
#    '2. high': '61.2200',
#    '3. low': '53.1000',
#    '4. close': '56.6000',
#    '5. volume': '112066500'},
#   '2007-10-31': {'1. open': '53.7500',
#    '2. high': '60.4900',
#    '3. low': '53.1500',
#    '4. close': '59.0200',
#    '5. volume': '88696700'},
#   '2007-09-28': {'1. open': '48.8800',
#    '2. high': '54.2700',
#    '3. low': '48.7000',
#    '4. close': '53.7500',
#    '5. volume': '73044500'},
#   '2007-08-31': {'1. open': '50.7900',
#    '2. high': '52.4600',
#    '3. low': '45.4700',
#    '4. close': '48.9800',
#    '5. volume': '110161600'},
#   '2007-07-31': {'1. open': '52.3400',
#    '2. high': '54.9700',
#    '3. low': '48.3000',
#    '4. close': '50.3300',
#    '5. volume': '90375400'},
#   '2007-06-29': {'1. open': '49.8300',
#    '2. high': '55.8200',
#    '3. low': '48.5500',
#    '4. close': '51.9900',
#    '5. volume': '107412400'},
#   '2007-05-31': {'1. open': '45.8700',
#    '2. high': '49.9900',
#    '3. low': '44.5600',
#    '4. close': '49.6500',
#    '5. volume': '110864600'},
#   '2007-04-30': {'1. open': '43.4000',
#    '2. high': '48.1600',
#    '3. low': '43.0000',
#    '4. close': '46.6600',
#    '5. volume': '95685000'},
#   '2007-03-30': {'1. open': '39.7600',
#    '2. high': '43.5800',
#    '3. low': '38.4000',
#    '4. close': '42.9800',
#    '5. volume': '142731900'},
#   '2007-02-28': {'1. open': '44.1000',
#    '2. high': '44.8700',
#    '3. low': '39.5500',
#    '4. close': '40.2900',
#    '5. volume': '107859700'},
#   '2007-01-31': {'1. open': '42.3700',
#    '2. high': '44.1700',
#    '3. low': '40.1600',
#    '4. close': '43.7500',
#    '5. volume': '110652400'},
#   '2006-12-29': {'1. open': '49.0900',
#    '2. high': '50.5000',
#    '3. low': '42.0100',
#    '4. close': '43.5200',
#    '5. volume': '113095100'},
#   '2006-11-30': {'1. open': '46.1900',
#    '2. high': '50.0200',
#    '3. low': '45.5300',
#    '4. close': '49.3600',
#    '5. volume': '86904900'},
#   '2006-10-31': {'1. open': '43.6800',
#    '2. high': '47.7600',
#    '3. low': '39.5100',
#    '4. close': '46.4200',
#    '5. volume': '94229900'},
#   '2006-09-29': {'1. open': '47.7500',
#    '2. high': '50.6700',
#    '3. low': '40.4000',
#    '4. close': '43.8300',
#    '5. volume': '118846600'},
#   '2006-08-31': {'1. open': '45.7400',
#    '2. high': '49.0000',
#    '3. low': '43.8400',
#    '4. close': '46.9100',
#    '5. volume': '99377700'},
#   '2006-07-31': {'1. open': '48.7000',
#    '2. high': '48.9900',
#    '3. low': '41.5000',
#    '4. close': '45.7400',
#    '5. volume': '97186600'},
#   '2006-06-30': {'1. open': '49.2200',
#    '2. high': '58.0000',
#    '3. low': '42.4000',
#    '4. close': '47.6900',
#    '5. volume': '135821800'},
#   '2006-05-31': {'1. open': '105.7500',
#    '2. high': '110.0200',
#    '3. low': '48.5700',
#    '4. close': '49.6700',
#    '5. volume': '60324250'},
#   '2006-04-28': {'1. open': '102.0500',
#    '2. high': '113.9500',
#    '3. low': '101.7000',
#    '4. close': '104.8200',
#    '5. volume': '41438300'},
#   '2006-03-31': {'1. open': '99.6000',
#    '2. high': '104.7000',
#    '3. low': '92.8500',
#    '4. close': '101.0100',
#    '5. volume': '55921700'},
#   '2006-02-28': {'1. open': '107.8200',
#    '2. high': '109.1300',
#    '3. low': '94.8000',
#    '4. close': '99.1600',
#    '5. volume': '51558100'},
#   '2006-01-31': {'1. open': '95.5000',
#    '2. high': '110.1500',
#    '3. low': '94.7000',
#    '4. close': '107.8200',
#    '5. volume': '52370400'},
#   '2005-12-30': {'1. open': '91.1000',
#    '2. high': '101.4200',
#    '3. low': '91.0000',
#    '4. close': '94.7500',
#    '5. volume': '50134200'},
#   '2005-11-30': {'1. open': '89.2500',
#    '2. high': '93.4800',
#    '3. low': '83.8000',
#    '4. close': '90.6100',
#    '5. volume': '48587900'},
#   '2005-10-31': {'1. open': '96.5500',
#    '2. high': '96.8500',
#    '3. low': '83.9000',
#    '4. close': '90.7100',
#    '5. volume': '66395600'},
#   '2005-09-30': {'1. open': '91.8500',
#    '2. high': '98.9700',
#    '3. low': '90.3600',
#    '4. close': '95.7500',
#    '5. volume': '44191900'},
#   '2005-08-31': {'1. open': '88.6500',
#    '2. high': '92.2600',
#    '3. low': '84.4700',
#    '4. close': '90.8700',
#    '5. volume': '45834400'},
#   '2005-07-29': {'1. open': '82.5800',
#    '2. high': '90.4500',
#    '3. low': '82.5200',
#    '4. close': '88.3500',
#    '5. volume': '41843600'},
#   '2005-06-30': {'1. open': '76.1500',
#    '2. high': '84.8400',
#    '3. low': '75.2900',
#    '4. close': '82.1500',
#    '5. volume': '41924800'},
#   '2005-05-31': {'1. open': '72.5600',
#    '2. high': '76.2100',
#    '3. low': '67.7100',
#    '4. close': '75.7000',
#    '5. volume': '45244900'},
#   '2005-04-29': {'1. open': '76.6700',
#    '2. high': '80.1400',
#    '3. low': '70.2500',
#    '4. close': '73.0400',
#    '5. volume': '52014400'},
#   '2005-03-31': {'1. open': '76.5500',
#    '2. high': '81.8100',
#    '3. low': '71.6500',
#    '4. close': '76.1000',
#    '5. volume': '57976200'},
#   '2005-02-28': {'1. open': '66.3500',
#    '2. high': '79.2900',
#    '3. low': '64.9100',
#    '4. close': '76.8600',
#    '5. volume': '50622700'},
#   '2005-01-31': {'1. open': '64.3500',
#    '2. high': '66.5000',
#    '3. low': '60.0200',
#    '4. close': '66.2100',
#    '5. volume': '40953400'},
#   '2004-12-31': {'1. open': '69.7000',
#    '2. high': '69.9600',
#    '3. low': '64.0500',
#    '4. close': '64.8100',
#    '5. volume': '41330000'},
#   '2004-11-30': {'1. open': '67.7500',
#    '2. high': '70.4400',
#    '3. low': '65.3400',
#    '4. close': '69.6000',
#    '5. volume': '47503600'},
#   '2004-10-29': {'1. open': '66.8000',
#    '2. high': '71.5500',
#    '3. low': '65.4700',
#    '4. close': '67.4500',
#    '5. volume': '43095300'},
#   '2004-09-30': {'1. open': '59.3200',
#    '2. high': '67.4700',
#    '3. low': '59.1700',
#    '4. close': '66.3600',
#    '5. volume': '32801500'},
#   '2004-08-31': {'1. open': '59.7900',
#    '2. high': '60.2000',
#    '3. low': '55.5200',
#    '4. close': '59.2200',
#    '5. volume': '39242000'},
#   '2004-07-30': {'1. open': '58.5900',
#    '2. high': '61.2200',
#    '3. low': '57.5800',
#    '4. close': '59.7900',
#    '5. volume': '33321700'},
#   '2004-06-30': {'1. open': '54.8000',
#    '2. high': '60.0000',
#    '3. low': '54.6800',
#    '4. close': '58.6000',
#    '5. volume': '36814200'},
#   '2004-05-28': {'1. open': '54.0000',
#    '2. high': '57.0300',
#    '3. low': '52.7500',
#    '4. close': '54.5200',
#    '5. volume': '35447700'},
#   '2004-04-30': {'1. open': '52.0000',
#    '2. high': '56.9100',
#    '3. low': '50.7500',
#    '4. close': '53.5800',
#    '5. volume': '36120400'},
#   '2004-03-31': {'1. open': '51.3300',
#    '2. high': '53.9500',
#    '3. low': '50.3900',
#    '4. close': '51.8600',
#    '5. volume': '36008400'},
#   '2004-02-27': {'1. open': '50.7000',
#    '2. high': '52.2700',
#    '3. low': '48.5000',
#    '4. close': '51.2500',
#    '5. volume': '36113600'},
#   '2004-01-30': {'1. open': '51.0200',
#    '2. high': '52.9900',
#    '3. low': '48.0000',
#    '4. close': '49.9000',
#    '5. volume': '45563500'},
#   '2003-12-31': {'1. open': '45.0100',
#    '2. high': '51.7200',
#    '3. low': '44.8500',
#    '4. close': '51.0100',
#    '5. volume': '41043800'},
#   '2003-11-28': {'1. open': '43.6000',
#    '2. high': '45.1400',
#    '3. low': '42.6000',
#    '4. close': '44.9300',
#    '5. volume': '31778700'},
#   '2003-10-31': {'1. open': '41.7500',
#    '2. high': '43.6900',
#    '3. low': '40.8300',
#    '4. close': '43.6200',
#    '5. volume': '45428500'},
#   '2003-09-30': {'1. open': '43.5000',
#    '2. high': '44.7700',
#    '3. low': '40.8000',
#    '4. close': '41.7600',
#    '5. volume': '51248700'},
#   '2003-08-29': {'1. open': '44.0000',
#    '2. high': '45.7000',
#    '3. low': '40.2700',
#    '4. close': '43.5000',
#    '5. volume': '60050100'},
#   '2003-07-31': {'1. open': '44.5800',
#    '2. high': '46.0000',
#    '3. low': '41.5100',
#    '4. close': '43.8000',
#    '5. volume': '77077900'},
#   '2003-06-30': {'1. open': '49.4500',
#    '2. high': '50.4000',
#    '3. low': '43.5900',
#    '4. close': '44.4700',
#    '5. volume': '79030400'},
#   '2003-05-30': {'1. open': '44.5000',
#    '2. high': '50.1500',
#    '3. low': '44.2900',
#    '4. close': '49.2800',
#    '5. volume': '42217500'},
#   '2003-04-30': {'1. open': '45.6500',
#    '2. high': '47.2500',
#    '3. low': '43.5000',
#    '4. close': '44.4000',
#    '5. volume': '39240800'},
#   '2003-03-31': {'1. open': '46.1000',
#    '2. high': '46.9300',
#    '3. low': '42.9500',
#    '4. close': '45.5000',
#    '5. volume': '51274300'},
#   '2003-02-28': {'1. open': '46.1200',
#    '2. high': '47.5000',
#    '3. low': '41.9300',
#    '4. close': '46.0800',
#    '5. volume': '38250100'},
#   '2003-01-31': {'1. open': '48.1300',
#    '2. high': '49.0900',
#    '3. low': '43.5000',
#    '4. close': '46.1100',
#    '5. volume': '37539000'},
#   '2002-12-31': {'1. open': '47.6900',
#    '2. high': '50.4900',
#    '3. low': '47.0500',
#    '4. close': '47.9000',
#    '5. volume': '36796300'},
#   '2002-11-29': {'1. open': '44.7400',
#    '2. high': '47.5500',
#    '3. low': '43.4500',
#    '4. close': '47.2000',
#    '5. volume': '30384200'},
#   '2002-10-31': {'1. open': '44.5400',
#    '2. high': '48.6300',
#    '3. low': '41.7000',
#    '4. close': '44.5400',
#    '5. volume': '40717000'},
#   '2002-09-30': {'1. open': '44.0500',
#    '2. high': '45.7800',
#    '3. low': '40.7100',
#    '4. close': '44.5400',
#    '5. volume': '30047800'},
#   '2002-08-30': {'1. open': '43.3500',
#    '2. high': '45.6000',
#    '3. low': '39.1200',
#    '4. close': '44.6400',
#    '5. volume': '38282000'},
#   '2002-07-31': {'1. open': '49.3000',
#    '2. high': '49.3600',
#    '3. low': '36.7700',
#    '4. close': '43.5000',
#    '5. volume': '40748300'},
#   '2002-06-28': {'1. open': '50.9500',
#    '2. high': '51.0500',
#    '3. low': '46.2500',
#    '4. close': '49.3000',
#    '5. volume': '31904300'},
#   '2002-05-31': {'1. open': '53.1900',
#    '2. high': '54.9000',
#    '3. low': '49.8100',
#    '4. close': '50.7500',
#    '5. volume': '31042300'},
#   '2002-04-30': {'1. open': '57.6000',
#    '2. high': '58.1300',
#    '3. low': '51.8000',
#    '4. close': '53.8200',
#    '5. volume': '41216500'},
#   '2002-03-28': {'1. open': '51.2000',
#    '2. high': '58.5500',
#    '3. low': '51.1500',
#    '4. close': '56.4400',
#    '5. volume': '35097700'},
#   '2002-02-28': {'1. open': '50.1000',
#    '2. high': '53.0000',
#    '3. low': '46.4000',
#    '4. close': '52.1000',
#    '5. volume': '33146400'},
#   '2002-01-31': {'1. open': '55.2000',
#    '2. high': '55.9000',
#    '3. low': '43.7000',
#    '4. close': '49.1300',
#    '5. volume': '62438600'},
#   '2001-12-31': {'1. open': '53.3000',
#    '2. high': '57.9000',
#    '3. low': '50.5200',
#    '4. close': '56.8500',
#    '5. volume': '43019500'},
#   '2001-11-30': {'1. open': '57.2000',
#    '2. high': '59.5000',
#    '3. low': '50.1000',
#    '4. close': '51.9000',
#    '5. volume': '55713200'},
#   '2001-10-31': {'1. open': '48.0800',
#    '2. high': '61.7500',
#    '3. low': '46.0000',
#    '4. close': '57.0500',
#    '5. volume': '60202100'},
#   '2001-09-28': {'1. open': '52.3000',
#    '2. high': '54.6000',
#    '3. low': '43.0000',
#    '4. close': '48.0800',
#    '5. volume': '44749100'},
#   '2001-08-31': {'1. open': '57.8000',
#    '2. high': '60.0000',
#    '3. low': '51.5000',
#    '4. close': '51.7500',
#    '5. volume': '55561800'},
#   '2001-07-31': {'1. open': '54.4500',
#    '2. high': '60.0000',
#    '3. low': '46.5200',
#    '4. close': '56.8000',
#    '5. volume': '67414700'},
#   '2001-06-29': {'1. open': '61.7500',
#    '2. high': '64.1500',
#    '3. low': '53.1000',
#    '4. close': '53.9100',
#    '5. volume': '62547200'},
#   '2001-05-31': {'1. open': '64.0500',
#    '2. high': '69.1800',
#    '3. low': '59.3000',
#    '4. close': '62.6100',
#    '5. volume': '65608300'},
#   '2001-04-30': {'1. open': '62.7300',
#    '2. high': '69.3900',
#    '3. low': '56.2000',
#    '4. close': '64.6200',
#    '5. volume': '55676000'},
#   '2001-03-30': {'1. open': '62.6000',
#    '2. high': '73.0000',
#    '3. low': '59.0000',
#    '4. close': '62.7800',
#    '5. volume': '62698900'},
#   '2001-02-28': {'1. open': '58.0000',
#    '2. high': '69.8900',
#    '3. low': '53.9500',
#    '4. close': '62.5000',
#    '5. volume': '49227900'},
#   '2001-01-31': {'1. open': '71.0800',
#    '2. high': '73.9700',
#    '3. low': '55.6500',
#    '4. close': '56.9000',
#    '5. volume': '53543400'},
#   '2000-12-29': {'1. open': '59.7000',
#    '2. high': '75.9500',
#    '3. low': '58.4500',
#    '4. close': '71.0800',
#    '5. volume': '34548000'},
#   '2000-11-30': {'1. open': '65.1000',
#    '2. high': '68.2500',
#    '3. low': '56.0000',
#    '4. close': '59.5000',
#    '5. volume': '36846000'},
#   '2000-10-31': {'1. open': '67.8000',
#    '2. high': '74.5500',
#    '3. low': '59.0000',
#    '4. close': '64.0500',
#    '5. volume': '48416900'},
#   '2000-09-29': {'1. open': '65.8000',
#    '2. high': '69.7500',
#    '3. low': '58.8000',
#    '4. close': '66.4600',
#    '5. volume': '37517200'},
#   '2000-08-31': {'1. open': '47.9400',
#    '2. high': '65.9500',
#    '3. low': '47.8800',
#    '4. close': '65.7900',
#    '5. volume': '47655700'},
#   '2000-07-31': {'1. open': '49.5000',
#    '2. high': '51.8800',
#    '3. low': '44.2500',
#    '4. close': '47.8800',
#    '5. volume': '34385800'},
#   '2000-06-30': {'1. open': '53.3800',
#    '2. high': '53.7500',
#    '3. low': '48.5000',
#    '4. close': '49.3100',
#    '5. volume': '30253000'},
#   '2000-05-31': {'1. open': '44.0000',
#    '2. high': '53.1900',
#    '3. low': '43.0000',
#    '4. close': '52.2500',
#    '5. volume': '45893400'},
#   '2000-04-28': {'1. open': '35.3800',
#    '2. high': '44.5000',
#    '3. low': '33.2500',
#    '4. close': '43.4400',
#    '5. volume': '40756900'},
#   '2000-03-31': {'1. open': '30.8800',
#    '2. high': '40.0000',
#    '3. low': '29.5000',
#    '4. close': '38.6900',
#    '5. volume': '26925200'},
#   '2000-02-29': {'1. open': '33.0600',
#    '2. high': '34.3800',
#    '3. low': '27.5600',
#    '4. close': '30.7500',
#    '5. volume': '12627300'},
#   '2000-01-31': {'1. open': '34.0000',
#    '2. high': '36.8800',
#    '3. low': '31.8800',
#    '4. close': '32.8100',
#    '5. volume': '11986300'},
#   '1999-12-31': {'1. open': '30.0600',
#    '2. high': '34.4400',
#    '3. low': '28.3800',
#    '4. close': '34.1300',
#    '5. volume': '15147500'}},
#  {'1. Information': 'Monthly Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'APC',
#   '3. Last Refreshed': '2019-08-08',
#   '4. Time Zone': 'US/Eastern'})
